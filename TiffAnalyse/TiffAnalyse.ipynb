# %%
from construct import *

data = None
tiff_file = 'data/data.NEF'
with open(tiff_file, 'rb') as f:
    data = f.read()

# %% [markdown]
# # TIFF
#
# 参考标准 [TIFF6.0](https://web.archive.org/web/20180810205359/https://www.adobe.io/content/udp/en/open/standards/TIFF/_jcr_content/contentbody/download/file.res/TIFF6.pdf)
#
# # TIFF Struct
#
# TIFF 文件最大为 2**32 bytes, 也就是 4GB.
#
# TIFF 由一个 **Image File Header 和若干个 **Image File Directory(IFD)** 以及实际的数据组成
#
# 结构图如下:
#
# ![图 1](../asset/bf5757e490b74e3036f7972526d2a99880ec61076cf0aa2a13c01d45854089ac.png)

# %% [markdown]
# ## Image File Header
#
# 头部信息一共 8 个字节
#
# - Bytes 0-1: 指示大小端
#     - II(0x49 0x49): 小端字节序
#     - MM(0x4D 0x4D): 大端字节序
# - Bytes 2-3: 固定值 42, 进一步标识该文件为 TIFF 文件
#     - 小端序: 0x2A 0x00
#     - 大端序: 0x00 0x2A
# - Bytes 4-7: 指向第一个 IFD 的 offset, 第一个 IFD 可能存在于 Image File Header 之后的任意地方, 但其偏移必须是偶数
#
# ![图 2](../asset/4371d66ff58c949220a99dd41aa537f9404921f1914bd995d0ecb6f6bab07a43.png)

# %% [markdown]
# ## Image File Directory(IFD)
#
# 每个 TIFF 文件必须要有至少一个 IFD, 而每个 IFD 至少有一个 IFD Entry
#
# IFD的结构为:
#
# - Bytes 0-1: 指示 IFD 中包含 IFD Entry 的数量, 这里假设为 B
# - 随后的 12 * B 个字节: 这里包含了 B 个 DE, 每个 DE 大小为 12 Bytes
# - 随后的 4 个字节: 下一个 IFD 的偏移量, 如果为 0, 则表示当前为最后一个 IFD
#
# ![图 1](../asset/bf5757e490b74e3036f7972526d2a99880ec61076cf0aa2a13c01d45854089ac.png)

# %% [markdown]
# ### IFD Entry
#
# 每个 IFD Entry 为 12 Bytes
#
# 结构如下:
# - Bytes 0-1: Tag
# - Bytes 2-3: Type
# - Bytes 4-7: Value 的数量
# - Bytes 8-11: Value 的值 或 Value 的起始 offset, 取决于 Type, offset 可以在文件的任何地方, offset 必须是偶数
#
# ![图 3](../asset/2e76318ec5802dd5faeebad564cce5fd2b35b16e95b76ae3b2cb3f7c8b3029ce.png)

# %%
# %run TiffTag.py

class TIFF:
    def __init__(self, data):
        self.data = data
        self.is_little = data[:2] == b'II'
        self.header_fmt = Struct(
            "ByteOrder" / Bytes(2),
            "MagicNum" / BytesInteger(2, swapped=self.is_little),
            "FirstIFDOffset" / BytesInteger(4, swapped=self.is_little),
        )

        self.IFD_entry_fmt = Struct(
            "Tag" / BytesInteger(2, swapped=self.is_little),
            "Type" / BytesInteger(2, swapped=self.is_little),
            "Count" / BytesInteger(4, swapped=self.is_little),
            "Data" / BytesInteger(4, swapped=self.is_little),
        )

        self.IFD_fmt = Struct(
            "IFDEntryCount" / BytesInteger(2, swapped=self.is_little),
            "IFDEntries" / Array(this.IFDEntryCount, self.IFD_entry_fmt),
            "NextIFDOffset" / BytesInteger(4, swapped=self.is_little)
        )

        self.header = self.header_fmt.parse(self.data)
        self.IFDs = []
        self.tags_map = {}
        offset = self.header.FirstIFDOffset
        while True:
            ifd = self.IFD_fmt.parse(self.data[offset:])
            self.IFDs.append(ifd)

            for entry in ifd.IFDEntries:
                self.tags_map[entry.Tag] = (TAG[entry.Tag], entry)

            offset = ifd.NextIFDOffset
            if offset == 0:
                break

        tag_SubIFDs = self.tags_map[330][1]

        offset = tag_SubIFDs.Data
        ifd = self.IFD_fmt.parse(self.data[offset:])
        self.IFDs.append(ifd)

        for entry in ifd.IFDEntries:
            if entry.Tag in TAG:
                self.tags_map[entry.Tag] = (TAG[entry.Tag], entry)

        offset = ifd.NextIFDOffset
        self.sub_IFDs = ifd
        
    
    def __str__(self):
        ret = f'Header {self.header.__str__()}\n'
        ret += f'IFD count: {len(self.IFDs)}\n'
        for tag in self.tags_map.values():
            ret += f'{tag[0]} {tag[1].__str__()}\n'
        return ret

tiff = TIFF(data)
print(tiff)
# print(tiff.sub_IFDs)
# Out:
# Header Container:
#     ByteOrder = b'II' (total 2)
#     MagicNum = 42
#     FirstIFDOffset = 8
# IFD count: 2
# NewSubfileType Container:
#     Tag = 254
#     Type = 4
#     Count = 1
#     Data = 1
# ImageWidth Container:
#     Tag = 256
#     Type = 256
#     Count = 683081760
#     Data = 1944100266
# ImageLength Container:
#     Tag = 257
#     Type = 51454
#     Count = 3017577909
#     Data = 3192244888
# BitsPerSample Container:
#     Tag = 258
#     Type = 1026
#     Count = 117703428
#     Data = 263173
# Compression Container:
#     Tag = 259
#     Type = 3
#     Count = 1
#     Data = 6
# PhotometricInterpretation Container:
#     Tag = 262
#     Type = 3
#     Count = 1
#     Data = 2
# Make Container:
#     Tag = 271
#     Type = 2
#     Count = 18
#     Data = 324
# Model Container:
#     Tag = 272
#     Type = 52183
#     Count = 2200231862
#     Data = 3379389611
# StripOffsets Container:
#     Tag = 273
#     Type = 4
#     Count = 1
#     Data = 946870
# Orientation Container:
#     Tag = 274
#     Type = 3
#     Count = 1
#     Data = 1
# SamplesPerPixel Container:
#     Tag = 277
#     Type = 3
#     Count = 1
#     Data = 3
# RowsPerStrip Container:
#     Tag = 278
#     Type = 4
#     Count = 1
#     Data = 120
# StripByteCounts Container:
#     Tag = 279
#     Type = 4
#     Count = 1
#     Data = 57600
# XResolution Container:
#     Tag = 282
#     Type = 5
#     Count = 1
#     Data = 20422
# YResolution Container:
#     Tag = 283
#     Type = 58368
#     Count = 2675931662
#     Data = 848278734
# PlanarConfiguration Container:
#     Tag = 284
#     Type = 20430
#     Count = 2797037340
#     Data = 3420089213
# ResolutionUnit Container:
#     Tag = 296
#     Type = 3
#     Count = 1
#     Data = 2
# Software Container:
#     Tag = 305
#     Type = 2
#     Count = 11
#     Data = 372
# DateTime Container:
#     Tag = 306
#     Type = 2
#     Count = 20
#     Data = 384
# SubIFDs Container:
#     Tag = 330
#     Type = 4
#     Count = 2
#     Data = 404
# ReferenceBlackWhite Container:
#     Tag = 532
#     Type = 5
#     Count = 6
#     Data = 412
# XMP Container:
#     Tag = 700
#     Type = 1
#     Count = 2048
#     Data = 460
# ExifTag Container:
#     Tag = 34665
#     Type = 4
#     Count = 1
#     Data = 2528
# TVX_ExposureTime Container:
#     Tag = 36867
#     Type = 36260
#     Count = 2348900512
#     Data = 4235549855
# TIFFEPStandardID Container:
#     Tag = 37398
#     Type = 1
#     Count = 4
#     Data = 1
# ExposureTime Container:
#     Tag = 33434
#     Type = 5
#     Count = 1
#     Data = 2932
# FNumber Container:
#     Tag = 33437
#     Type = 5
#     Count = 1
#     Data = 2940
# ExposureProgram Container:
#     Tag = 34850
#     Type = 3
#     Count = 1
#     Data = 0
# PhotographicSensitivity Container:
#     Tag = 34855
#     Type = 3
#     Count = 1
#     Data = 800
# SensitivityType Container:
#     Tag = 34864
#     Type = 3
#     Count = 1
#     Data = 2
# TVX_BackgroundTime Container:
#     Tag = 36868
#     Type = 2
#     Count = 20
#     Data = 2968
# ExposureBiasValue Container:
#     Tag = 37380
#     Type = 10
#     Count = 1
#     Data = 2988
# MaxApertureValue Container:
#     Tag = 37381
#     Type = 5
#     Count = 1
#     Data = 2996
# MeteringMode Container:
#     Tag = 37383
#     Type = 3
#     Count = 1
#     Data = 5
# LightSource Container:
#     Tag = 37384
#     Type = 3
#     Count = 1
#     Data = 0
# Flash Container:
#     Tag = 37385
#     Type = 3
#     Count = 1
#     Data = 0
# FocalLength Container:
#     Tag = 37386
#     Type = 5
#     Count = 1
#     Data = 3004
# MakerNote Container:
#     Tag = 37500
#     Type = 7
#     Count = 943778
#     Data = 3092
# SubsecTime Container:
#     Tag = 37520
#     Type = 26199
#     Count = 481945590
#     Data = 4294765441
# SubsecTimeOriginal Container:
#     Tag = 37521
#     Type = 39836
#     Count = 64007494
#     Data = 357206372
# SubsecTimeDigitized Container:
#     Tag = 37522
#     Type = 2
#     Count = 3
#     Data = 12336
# SensingMethod Container:
#     Tag = 41495
#     Type = 58612
#     Count = 2666088578
#     Data = 3215513137
# FileSource Container:
#     Tag = 41728
#     Type = 7
#     Count = 1
#     Data = 3
# SceneType Container:
#     Tag = 41729
#     Type = 7
#     Count = 1
#     Data = 1
# CFAPattern Container:
#     Tag = 41730
#     Type = 7
#     Count = 8
#     Data = 3012
# CustomRendered Container:
#     Tag = 41985
#     Type = 3
#     Count = 1
#     Data = 0
# ExposureMode Container:
#     Tag = 41986
#     Type = 3
#     Count = 1
#     Data = 0
# WhiteBalance Container:
#     Tag = 41987
#     Type = 3
#     Count = 1
#     Data = 0
# DigitalZoomRatio Container:
#     Tag = 41988
#     Type = 5
#     Count = 1
#     Data = 3020
# FocalLengthIn35mmFilm Container:
#     Tag = 41989
#     Type = 3
#     Count = 1
#     Data = 27
# SceneCaptureType Container:
#     Tag = 41990
#     Type = 3
#     Count = 1
#     Data = 0
# GainControl Container:
#     Tag = 41991
#     Type = 3
#     Count = 1
#     Data = 1
# Contrast Container:
#     Tag = 41992
#     Type = 3
#     Count = 1
#     Data = 0
# Saturation Container:
#     Tag = 41993
#     Type = 3
#     Count = 1
#     Data = 0
# Sharpness Container:
#     Tag = 41994
#     Type = 3
#     Count = 1
#     Data = 0
# SubjectDistanceRange Container:
#     Tag = 41996
#     Type = 45770
#     Count = 1754708900
#     Data = 2063165791
# LensModel Container:
#     Tag = 42036
#     Type = 2
#     Count = 64
#     Data = 3028
# ColorMap Container:
#     Tag = 320
#     Type = 240
#     Count = 0
#     Data = 6357123
# AndorVerticalClockVoltage Container:
#     Tag = 4904
#     Type = 23333
#     Count = 751084713
#     Data = 2569785465
# InteroperabilityVersion Container:
#     Tag = 20546
#     Type = 19636
#     Count = 3115086969
#     Data = 119034942
# ImageDataDiscard Container:
#     Tag = 48324
#     Type = 11166
#     Count = 495484932
#     Data = 1806095670
# ConsecutiveBadFaxLines Container:
#     Tag = 328
#     Type = 328
#     Count = 21496136
#     Data = 257
# HalftoneHints Container:
#     Tag = 321
#     Type = 369
#     Count = 30474657
#     Data = 38535692
# JPEGInterchangeFormat Container:
#     Tag = 513
#     Type = 119
#     Count = 285409793
#     Data = 824247556
# OpcodeList3 Container:
#     Tag = 51022
#     Type = 59333
#     Count = 2732887088
#     Data = 2952182199
# FocalPlaneResolutionUnit Container:
#     Tag = 41488
#     Type = 11178
#     Count = 1438293537
#     Data = 1286095185
# JPEGInterchangeFormatLength Container:
#     Tag = 514
#     Type = 770
#     Count = 50529283
#     Data = 33752067
# YCbCrPositioning Container:
#     Tag = 531
#     Type = 3
#     Count = 1
#     Data = 2
# ICCProfileDescriptor Container:
#     Tag = 770
#     Type = 1284
#     Count = 151521030
#     Data = 1116938
# SRawType Container:
#     Tag = 50885
#     Type = 55868
#     Count = 1744710973
#     Data = 2634248647
# ProfileHueSatMapDims Container:
#     Tag = 50937
#     Type = 59704
#     Count = 1364853240
#     Data = 3708633260
# EnhanceParams Container:
#     Tag = 51182
#     Type = 35979
#     Count = 1681836963
#     Data = 3850983918
# GEO_METADATA Container:
#     Tag = 50909
#     Type = 20227
#     Count = 3165256746
#     Data = 509091571
# FlashpixVersion Container:
#     Tag = 40960
#     Type = 36467
#     Count = 4025891303
#     Data = 1491858652
# AndorEmDacLevel Container:
#     Tag = 4885
#     Type = 40068
#     Count = 293568078
#     Data = 1941041513
# JBIGOptions Container:
#     Tag = 34750
#     Type = 49132
#     Count = 4203253699
#     Data = 10470695
# ImageNumber Container:
#     Tag = 37393
#     Type = 14600
#     Count = 2561657112
#     Data = 1904497857
# HylaFAXFaxSubAddress Container:
#     Tag = 34909
#     Type = 19941
#     Count = 3325274463
#     Data = 2088412076
# ModelPixelScaleTag Container:
#     Tag = 33550
#     Type = 40588
#     Count = 1311735197
#     Data = 1460097224
# FocalPlaneYResolution Container:
#     Tag = 37391
#     Type = 11993
#     Count = 2496227490
#     Data = 1808058024
# PreviewSettingsName Container:
#     Tag = 50968
#     Type = 64680
#     Count = 822006913
#     Data = 2639248248
# SubfileType Container:
#     Tag = 255
#     Type = 30629
#     Count = 2596952187
#     Data = 3778737008
# CZ_SEM Container:
#     Tag = 34118
#     Type = 30129
#     Count = 1273318821
#     Data = 1252690460
# RawImageSegmentation Container:
#     Tag = 50752
#     Type = 12400
#     Count = 3753929522
#     Data = 1331393220
# OpcodeList1 Container:
#     Tag = 51008
#     Type = 62733
#     Count = 2952054728
#     Data = 2386210138
# CIP3Side Container:
#     Tag = 37436
#     Type = 18338
#     Count = 3238912875
#     Data = 3261207883
# SamsungRawPointersOffset Container:
#     Tag = 40976
#     Type = 480
#     Count = 1027726750
#     Data = 2338255671
# ProfileHueSatMapData2 Container:
#     Tag = 50939
#     Type = 13524
#     Count = 3332829400
#     Data = 52547301
# AsShotICCProfile Container:
#     Tag = 50831
#     Type = 7919
#     Count = 3569966028
#     Data = 830041453
# ThumbnailCompressedSize Container:
#     Tag = 20505
#     Type = 6307
#     Count = 495735931
#     Data = 1699121994
# DefaultImageColor Container:
#     Tag = 434
#     Type = 22572
#     Count = 1966863018
#     Data = 3888077629
# AlphaDataDiscard Container:
#     Tag = 48325
#     Type = 7344
#     Count = 3860304608
#     Data = 1171225066
# WangAnnotation Container:
#     Tag = 32932
#     Type = 32661
#     Count = 3469492780
#     Data = 3480485945
# JPEGProc Container:
#     Tag = 512
#     Type = 63613
#     Count = 1612920309
#     Data = 3897137423
# ThumbnailWhitePoint Container:
#     Tag = 20533
#     Type = 1145
#     Count = 3072569696
#     Data = 1677989744
# NumberOfInks Container:
#     Tag = 334
#     Type = 3818
#     Count = 1397165616
#     Data = 483772767
# OriginalDefaultCropSize Container:
#     Tag = 51091
#     Type = 2495
#     Count = 1006401589
#     Data = 3208841201
# CurrentICCProfile Container:
#     Tag = 50833
#     Type = 40318
#     Count = 4095485817
#     Data = 3865798055
# DepthFormat Container:
#     Tag = 51177
#     Type = 44294
#     Count = 2505118434
#     Data = 2992630517
# ISOSpeed Container:
#     Tag = 34867
#     Type = 54074
#     Count = 349777477
#     Data = 303679294
# PrintFlagsBleedWidth Container:
#     Tag = 20488
#     Type = 55155
#     Count = 118427302
#     Data = 3575308472
# ImageHeight Container:
#     Tag = 48257
#     Type = 40039
#     Count = 3623392019
#     Data = 4178857621
# Gamma Container:
#     Tag = 42240
#     Type = 50722
#     Count = 3802542601
#     Data = 2910646211
# OffsetTimeDigitized Container:
#     Tag = 36882
#     Type = 19387
#     Count = 423153917
#     Data = 1174835431
# OceIdentificationNumber Container:
#     Tag = 50217
#     Type = 45681
#     Count = 1580640459
#     Data = 17738832
# BrightnessValue Container:
#     Tag = 37379
#     Type = 20737
#     Count = 3539040980
#     Data = 905692340
# MODIPositioning Container:
#     Tag = 37681
#     Type = 28316
#     Count = 2121770535
#     Data = 3247106307
# AndorAccumulations Container:
#     Tag = 4879
#     Type = 25963
#     Count = 90395682
#     Data = 2438062788
# UIC3tag Container:
#     Tag = 33630
#     Type = 33350
#     Count = 337772598
#     Data = 3020650730
# DepthNear Container:
#     Tag = 51178
#     Type = 48281
#     Count = 68498291
#     Data = 3692918600
# FrameDelay Container:
#     Tag = 20736
#     Type = 29638
#     Count = 2665507031
#     Data = 543360153
# Acceleration Container:
#     Tag = 37892
#     Type = 61936
#     Count = 3013492626
#     Data = 2764483835
# AndorBaselineClamp Container:
#     Tag = 4912
#     Type = 56894
#     Count = 1571018652
#     Data = 2952476923
# HalftoneShape Container:
#     Tag = 20493
#     Type = 4338
#     Count = 714356496
#     Data = 61896357
# ChromaBlurRadius Container:
#     Tag = 50737
#     Type = 12783
#     Count = 2065651698
#     Data = 1887498734
# ResolutionXUnit Container:
#     Tag = 20481
#     Type = 27406
#     Count = 383871978
#     Data = 3604745763
# ThumbnailArtist Container:
#     Tag = 20532
#     Type = 47420
#     Count = 752838949
#     Data = 3457728751
# RelatedSoundFile Container:
#     Tag = 40964
#     Type = 41416
#     Count = 2950753358
#     Data = 4118776915
# ImageNumber Container:
#     Tag = 41489
#     Type = 21946
#     Count = 2775754030
#     Data = 62978075
# DepthMeasureType Container:
#     Tag = 51181
#     Type = 36412
#     Count = 4276417600
#     Data = 1432286356
# ColorMatrix1 Container:
#     Tag = 50721
#     Type = 13169
#     Count = 2451891207
#     Data = 2373164745
# GDAL_METADATA Container:
#     Tag = 42112
#     Type = 29343
#     Count = 3242823335
#     Data = 3058135268
# FocalPlaneXResolution Container:
#     Tag = 37390
#     Type = 20389
#     Count = 1128249172
#     Data = 4174050252
# FocalPlaneResolutionUnit Container:
#     Tag = 37392
#     Type = 30521
#     Count = 594018706
#     Data = 423641122
# BodySerialNumber Container:
#     Tag = 42033
#     Type = 52384
#     Count = 661135125
#     Data = 2481182990
# XPComment Container:
#     Tag = 40092
#     Type = 61300
#     Count = 86283402
#     Data = 3753784028
# DepthFar Container:
#     Tag = 51179
#     Type = 5383
#     Count = 3501996776
#     Data = 3025775945
# PrimaryChromaticities Container:
#     Tag = 319
#     Type = 13909
#     Count = 1731394577
#     Data = 1893242271
# ThumbnailEquipMake Container:
#     Tag = 20518
#     Type = 62804
#     Count = 1214669613
#     Data = 3291491876
# TVX_Unknown Container:
#     Tag = 36864
#     Type = 1713
#     Count = 3488800560
#     Data = 3984612583
# TVX_NumExposure Container:
#     Tag = 36865
#     Type = 48112
#     Count = 3084512536
#     Data = 2358457278
# CompositeImage Container:
#     Tag = 42080
#     Type = 29494
#     Count = 3629123474
#     Data = 3950111801
# AsShotWhiteXY Container:
#     Tag = 50729
#     Type = 53270
#     Count = 2537358523
#     Data = 730235276
# LinearizationTable Container:
#     Tag = 50712
#     Type = 57464
#     Count = 1675398803
#     Data = 2222948021
# KodakAPP3 Container:
#     Tag = 50003
#     Type = 16062
#     Count = 1112092752
#     Data = 63408473
# DataType Container:
#     Tag = 32996
#     Type = 44559
#     Count = 985480527
#     Data = 967357686
# GDIGamma Container:
#     Tag = 769
#     Type = 20029
#     Count = 3665818113
#     Data = 1300975823
# OffsetTimeOriginal Container:
#     Tag = 36881
#     Type = 46650
#     Count = 1081122609
#     Data = 1752726190
# HalftoneLPI Container:
#     Tag = 20490
#     Type = 59239
#     Count = 2391706808
#     Data = 1453833010
# MC_ZPosition Container:
#     Tag = 50290
#     Type = 39966
#     Count = 511680001
#     Data = 237403461
# Noise Container:
#     Tag = 37389
#     Type = 36004
#     Count = 3810556162
#     Data = 2053929090
# JPEGDCTables Container:
#     Tag = 520
#     Type = 37092
#     Count = 1183860690
#     Data = 2358350707
# NewRawImageDigest Container:
#     Tag = 51111
#     Type = 12871
#     Count = 416002941
#     Data = 3062424577
# AdventRevision Container:
#     Tag = 33590
#     Type = 16996
#     Count = 1834660495
#     Data = 2302018055
# TimeCodes Container:
#     Tag = 51043
#     Type = 7149
#     Count = 657362559
#     Data = 3796827712
# FillOrder Container:
#     Tag = 266
#     Type = 51005
#     Count = 3044629679
#     Data = 1690504434
# CacheBlob Container:
#     Tag = 51113
#     Type = 43270
#     Count = 3279903699
#     Data = 16750751
# AliasLayerMetadata Container:
#     Tag = 50784
#     Type = 52039
#     Count = 2860445904
#     Data = 3411562879
# OriginalRawFileDigest Container:
#     Tag = 50973
#     Type = 30044
#     Count = 3651971535
#     Data = 840215918
# Matteing Container:
#     Tag = 32995
#     Type = 28731
#     Count = 1307243520
#     Data = 1418377337
# CameraCalibrationSignature Container:
#     Tag = 50931
#     Type = 32382
#     Count = 2451317831
#     Data = 1043909543
# FreeOffsets Container:
#     Tag = 288
#     Type = 1666
#     Count = 1587508016
#     Data = 2799843480
# OriginalBestQualitySize Container:
#     Tag = 51090
#     Type = 61345
#     Count = 1697992606
#     Data = 1720381424
# ISOSpeedLatitudeyyy Container:
#     Tag = 34868
#     Type = 27930
#     Count = 1458539195
#     Data = 130593565
# SRGBRenderingIntent Container:
#     Tag = 771
#     Type = 40764
#     Count = 3344793499
#     Data = 2874101480
# MM_UserBlock Container:
#     Tag = 34386
#     Type = 32230
#     Count = 275329227
#     Data = 680586596
# ThumbnailYCbCrCoefficients Container:
#     Tag = 20535
#     Type = 14740
#     Count = 2094949271
#     Data = 2030275527
# Artist Container:
#     Tag = 315
#     Type = 31174
#     Count = 28506831
#     Data = 3072845762
# ExpandFilm Container:
#     Tag = 44994
#     Type = 30999
#     Count = 540581225
#     Data = 2062747873
# FibicsXML Container:
#     Tag = 51023
#     Type = 23025
#     Count = 3816666193
#     Data = 1005800436
# ImageResources Container:
#     Tag = 34377
#     Type = 63271
#     Count = 2188616842
#     Data = 2665988467
# IndexTransparent Container:
#     Tag = 20740
#     Type = 10094
#     Count = 4018014154
#     Data = 837956248
# Uncompressed Container:
#     Tag = 48131
#     Type = 64996
#     Count = 92577505
#     Data = 1465179369
# PrintFlags Container:
#     Tag = 20485
#     Type = 51373
#     Count = 1232134176
#     Data = 4194417925
# ThumbnailPhotometricInterp Container:
#     Tag = 20516
#     Type = 16779
#     Count = 11517041
#     Data = 2360906524
# FaxProfile Container:
#     Tag = 402
#     Type = 46189
#     Count = 3437470604
#     Data = 1870534122
# HeightResolution Container:
#     Tag = 48259
#     Type = 28774
#     Count = 522459459
#     Data = 3219797979
# TVX_SubHigh Container:
#     Tag = 36875
#     Type = 59518
#     Count = 3990368
#     Data = 2067545906
# XPTitle Container:
#     Tag = 40091
#     Type = 33425
#     Count = 2596119102
#     Data = 3570148277
# MODIOLEPropertySetStorage Container:
#     Tag = 37680
#     Type = 28054
#     Count = 494338303
#     Data = 2501851974
# DefaultBlackRender Container:
#     Tag = 51110
#     Type = 9044
#     Count = 1492623950
#     Data = 3137575090
# TVIPS2 Container:
#     Tag = 37708
#     Type = 22856
#     Count = 55283997
#     Data = 777225462
# FocalPlaneYResolution Container:
#     Tag = 41487
#     Type = 20208
#     Count = 3774173566
#     Data = 1255626609
# DNGBackwardVersion Container:
#     Tag = 50707
#     Type = 45618
#     Count = 3847450221
#     Data = 1025967040
# TStop Container:
#     Tag = 51058
#     Type = 33305
#     Count = 2424577105
#     Data = 313129843
# AndorExposureTime Container:
#     Tag = 4876
#     Type = 29404
#     Count = 3983790129
#     Data = 4041350111
# WangTag1 Container:
#     Tag = 32931
#     Type = 62094
#     Count = 4027046406
#     Data = 3835749348
# WhiteLevel Container:
#     Tag = 50717
#     Type = 48682
#     Count = 2964361149
#     Data = 712325082
# SampleFormat Container:
#     Tag = 339
#     Type = 61387
#     Count = 3389914819
#     Data = 2521279320
# FaxDcs Container:
#     Tag = 34911
#     Type = 30746
#     Count = 2454868877
#     Data = 1690274157
# MDColorTable Container:
#     Tag = 33447
#     Type = 61037
#     Count = 2495112143
#     Data = 3675852834
# T4Options Container:
#     Tag = 292
#     Type = 18486
#     Count = 1672528440
#     Data = 1093845755
# CurrentPreProfileMatrix Container:
#     Tag = 50834
#     Type = 46028
#     Count = 108208068
#     Data = 2649060314
# AntiAliasStrength Container:
#     Tag = 50738
#     Type = 30434
#     Count = 1245729938
#     Data = 999465874
# FieldOfViewCotangent Container:
#     Tag = 33304
#     Type = 7175
#     Count = 253688067
#     Data = 3981103017
# ProfileLookTableDims Container:
#     Tag = 50981
#     Type = 63127
#     Count = 2319611302
#     Data = 55275632
# ThumbnailFormat Container:
#     Tag = 20498
#     Type = 63896
#     Count = 3827066652
#     Data = 2625316067
# ChromaticAberrationCorrParams Container:
#     Tag = 28725
#     Type = 56970
#     Count = 3973907522
#     Data = 3116260879
# AndorHorizontalFlip Container:
#     Tag = 4896
#     Type = 14542
#     Count = 1789883898
#     Data = 3283452094
# StitchInfo Container:
#     Tag = 18248
#     Type = 1688
#     Count = 1376734834
#     Data = 4094193834
# ModelTiepointTag Container:
#     Tag = 33922
#     Type = 52980
#     Count = 4112047687
#     Data = 4172648157
# ImageDepth Container:
#     Tag = 32997
#     Type = 12511
#     Count = 2998192967
#     Data = 3830931762
# SenderName Container:
#     Tag = 40003
#     Type = 44661
#     Count = 1198949023
#     Data = 3434884655
# KodakIFD Container:
#     Tag = 33424
#     Type = 62067
#     Count = 2638104464
#     Data = 1769767345
# PrintImageMatching Container:
#     Tag = 50341
#     Type = 26768
#     Count = 3029427386
#     Data = 2252547182
# MakerNoteSafety Container:
#     Tag = 50741
#     Type = 27640
#     Count = 4236480481
#     Data = 2890901801
# CR2CFAPattern Container:
#     Tag = 50656
#     Type = 57714
#     Count = 1504269801
#     Data = 3458116091
# CalibrationIlluminant2 Container:
#     Tag = 50779
#     Type = 4543
#     Count = 1471497168
#     Data = 2533734210
